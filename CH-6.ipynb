# %% [markdown]
# Working With Files

# %%
import sys

# %%
sys.version
# Out:
# '3.12.10 (tags/v3.12.10:0cc8128, Apr  8 2025, 12:21:36) [MSC v.1943 64 bit (AMD64)]'

# %%
f = open('abc.txt','w')

# %%
f.write("HP")
# Out:
# 2

# %%
f.close()

# %%
f = open('abc.txt','w')
f.write("")
f.close()

# %%
f=open("file1.txt",'w')
f.write("Hello world\n")
f.write("I'm your Laptop LOQ")
f.close()

# %%
f=open("file2.txt",'w')
f.writelines("Hello world\n\n")
f.writelines("I'm your Laptop LOQ")
f.close()

# %%
F=open("file1.txt")
F.read()
# Out:
# "Hello world\nI'm your Laptop LOQ\nI'm  a very poweful laptop\nI have a i5 - 13450 hx processor a very powerful one\nAnd with  Geforce Nviia RTX 3050 Graphics card"

# %%
F.read()
# Out:
# ''

# %%
F.seek(0)
# Out:
# 0

# %%
F.read()
# Out:
# "Hello world\nI'm your Laptop LOQ\nI'm  a very poweful laptop\nI have a i5 - 13450 hx processor a very powerful one\nAnd with  Geforce Nviia RTX 3050 Graphics card"

# %%
F.tell()
# Out:
# 162

# %%
f=open("file3.txt",'w')
f.write("python\n")
f.write("programming")
F.close()

# %%
f=open("file3.txt")
f.read(4)
f.read(4)
# Out:
# 'on\np'

# %%
f.seek(0)
f.read()
# Out:
# 'python\nprogramming'

# %%
f.tell()
# Out:
# 19

# %%
f=open("abc.txt")
f.read(4)
print(f.tell())
f.read(4)
# Out:
# 4
# 'on\np'

# %%
f.seek(0)
# Out:
# 0

# %%
print(f.readline(19))
print(f.readline(-1))
# Out:
# python
#
# programming

# %%
print(f.readlines())
# Out:
# []

# %%
f=open("file5.txt",'w')
f.write("This is \n")
f.write("Pyhton Programming")
f.close()

# %%
f=open("file5.txt")
content=f.read()

# %%
for i in content:
    print(i,end="")
# Out:
# This is
# Pyhton Programming

# %%
# WAP To find total number of vowels in given file
count=0
for i in content:
    if i in ('a','e','i','o','u','A','E','I','O','U'):
        count+=1
print(f"{count} is total number of vowels")
# Out:
# 6 is total number of vowels

# %%
f.seek(0)
# Out:
# 0

# %%
print(f.read().split())
# Out:
# ['This', 'is', 'Pyhton', 'Programming']

# %%
# WAP TO find total number if vowels total characters total words from the given file
F=open("alice_in_wonderland.txt")
content=F.read()
count=0
count_vowels=0
count_consonants=0
count_punct=0
for i in content:
    if i in ('a','e','i','o','u','A','E','I','O','U'):
        count_vowels+=1
    elif i.isalpha()==True or not ('a','e','i','o','u','A','E','I','O','U'):
        count_consonants+=1
    else:
        count_punct+=1
F.seek(0)
print(f"{len(F.read().split())} is total number of words")
print(f"{count_vowels} is total number of vowels")
print(f"{count_consonants} is total number of consonants")
print(f"{count_punct} is total numbers of space and punctuation")
# Out:
# 26470 is total number of words
# 41505 is total number of vowels
# 66239 is total number of consonants
# 40830 is total numbers of space and punctuation

# %%
F.seek(0)
# Out:
# 0

# %%
#WAP 
A=open("File6.txt",'w')
for i in range(4):
    A.write(f"This is line {i+1}\n")
A.write(f"This is line {i+2}")
A.close()
print("File has been created and String has been inserted")
# Out:
# File has been created and String has been inserted

# %%
# WAP to create a file named big.txt that contains 1000 lines having this is phython pogramming thousands times using only list comprehention
Big=open("big.txt")
for i in Big.readlines():
    print(i.split()[0])
# Out:
# This
# This
# This
# This
# This

# %%
F1=open("big.txt")
F2=open("file8.txt",'w')
count=1
for i in F1:
    F2.write(str(count)+' : '+i)
    count+=1
F2.close()

# %%
# WAP print in reverse
F1=open("Big.txt")
F2=open("file9.txt",'w')
STR=""
F=F1.readlines()
F1.seek(0)
count=1
print(F)
for i in F1:
    for j in F:
        j[::-1]
    if count==5:
        break
    F2.write(str(count)+" : "+str(count)+" "+j[::-1]+"\n")
    count+=1
F2.write(str(count)+" : "+str(count)+" "+j[::-1])
F2.close()
# Out:
# ['This is line\n', 'This is line\n', 'This is line\n', 'This is line\n', 'This is line']

# %%
F1=open("Big.txt")
F2=open("file10.txt",'w')
STR=""
F=F1.readlines()
F1.seek(0)
count=1
for i in F1:
    for j in F:
        A=[lambda K: F2.write(i.split()[::-1]) for i in F1.readlines()]
    if count==5:
        break
    F2.write(str(count)+" : "+A[count]+"\n")
    count+=1
F2.write(str(count)+" : "+A[count+2])
F2.close()

# %%
F1=open("file10.txt")
A=list()
for i in F1.readlines():
    for k in i:
        if k=='g':
            print('y',end="")
        else:
            print(k,end="")
# Out:
# This is Python proyramminy
# It is very Easy

# %%
F=open("big.txt")
F.seek(99999999999)
F.readline()
# Out:
# ''

# %%
#wap such that your solution asked for prompt to give file name and display the text file (only the first 25 lines) it should prompt the use to print
#to print next 25 lines or to quit
k=True
count=0
F=open(input("Enter name of the File"))
while(k):
    oldcount=count
    count+=250
    for i in range(oldcount,count):
        print(F.readline())
    print('Press 1 : if you want to print next 250 lines')
    print("press 2 : if you want to quit")
    Input=int(input("Enter your choice"))
    if Input==2:
        k=False
    if F.readline()=="":
        print("File is empty")
        k=False
# Out:
# Enter name of the File big.txt
# 1 This is python programming
#
# 2 This is python programming
#
# 3 This is python programming
#
# 4 This is python programming
#
# 5 This is python programming
#
# 6 This is python programming
#
# 7 This is python programming
#
# 8 This is python programming
#
# 9 This is python programming
#
# 10 This is python programming
#
# 11 This is python programming
#
# 12 This is python programming
#
# 13 This is python programming
#
# 14 This is python programming
#
# 15 This is python programming
#
# 16 This is python programming
#
# 17 This is python programming
#
# 18 This is python programming
#
# 19 This is python programming
#
# 20 This is python programming
#
# 21 This is python programming
#
# 22 This is python programming
#
# 23 This is python programming
#
# 24 This is python programming
#
# 25 This is python programming
#
# 26 This is python programming
#
# 27 This is python programming
#
# 28 This is python programming
#
# 29 This is python programming
#
# 30 This is python programming
#
# 31 This is python programming
#
# 32 This is python programming
#
# 33 This is python programming
#
# 34 This is python programming
#
# 35 This is python programming
#
# 36 This is python programming
#
# 37 This is python programming
#
# 38 This is python programming
#
# 39 This is python programming
#
# 40 This is python programming
#
# 41 This is python programming
#
# 42 This is python programming
#
# 43 This is python programming
#
# 44 This is python programming
#
# 45 This is python programming
#
# 46 This is python programming
#
# 47 This is python programming
#
# 48 This is python programming
#
# 49 This is python programming
#
# 50 This is python programming
#
# 51 This is python programming
#
# 52 This is python programming
#
# 53 This is python programming
#
# 54 This is python programming
#
# 55 This is python programming
#
# 56 This is python programming
#
# 57 This is python programming
#
# 58 This is python programming
#
# 59 This is python programming
#
# 60 This is python programming
#
# 61 This is python programming
#
# 62 This is python programming
#
# 63 This is python programming
#
# 64 This is python programming
#
# 65 This is python programming
#
# 66 This is python programming
#
# 67 This is python programming
#
# 68 This is python programming
#
# 69 This is python programming
#
# 70 This is python programming
#
# 71 This is python programming
#
# 72 This is python programming
#
# 73 This is python programming
#
# 74 This is python programming
#
# 75 This is python programming
#
# 76 This is python programming
#
# 77 This is python programming
#
# 78 This is python programming
#
# 79 This is python programming
#
# 80 This is python programming
#
# 81 This is python programming
#
# 82 This is python programming
#
# 83 This is python programming
#
# 84 This is python programming
#
# 85 This is python programming
#
# 86 This is python programming
#
# 87 This is python programming
#
# 88 This is python programming
#
# 89 This is python programming
#
# 90 This is python programming
#
# 91 This is python programming
#
# 92 This is python programming
#
# 93 This is python programming
#
# 94 This is python programming
#
# 95 This is python programming
#
# 96 This is python programming
#
# 97 This is python programming
#
# 98 This is python programming
#
# 99 This is python programming
#
# 100 This is python programming
#
# 101 This is python programming
#
# 102 This is python programming
#
# 103 This is python programming
#
# 104 This is python programming
#
# 105 This is python programming
#
# 106 This is python programming
#
# 107 This is python programming
#
# 108 This is python programming
#
# 109 This is python programming
#
# 110 This is python programming
#
# 111 This is python programming
#
# 112 This is python programming
#
# 113 This is python programming
#
# 114 This is python programming
#
# 115 This is python programming
#
# 116 This is python programming
#
# 117 This is python programming
#
# 118 This is python programming
#
# 119 This is python programming
#
# 120 This is python programming
#
# 121 This is python programming
#
# 122 This is python programming
#
# 123 This is python programming
#
# 124 This is python programming
#
# 125 This is python programming
#
# 126 This is python programming
#
# 127 This is python programming
#
# 128 This is python programming
#
# 129 This is python programming
#
# 130 This is python programming
#
# 131 This is python programming
#
# 132 This is python programming
#
# 133 This is python programming
#
# 134 This is python programming
#
# 135 This is python programming
#
# 136 This is python programming
#
# 137 This is python programming
#
# 138 This is python programming
#
# 139 This is python programming
#
# 140 This is python programming
#
# 141 This is python programming
#
# 142 This is python programming
#
# 143 This is python programming
#
# 144 This is python programming
#
# 145 This is python programming
#
# 146 This is python programming
#
# 147 This is python programming
#
# 148 This is python programming
#
# 149 This is python programming
#
# 150 This is python programming
#
# 151 This is python programming
#
# 152 This is python programming
#
# 153 This is python programming
#
# 154 This is python programming
#
# 155 This is python programming
#
# 156 This is python programming
#
# 157 This is python programming
#
# 158 This is python programming
#
# 159 This is python programming
#
# 160 This is python programming
#
# 161 This is python programming
#
# 162 This is python programming
#
# 163 This is python programming
#
# 164 This is python programming
#
# 165 This is python programming
#
# 166 This is python programming
#
# 167 This is python programming
#
# 168 This is python programming
#
# 169 This is python programming
#
# 170 This is python programming
#
# 171 This is python programming
#
# 172 This is python programming
#
# 173 This is python programming
#
# 174 This is python programming
#
# 175 This is python programming
#
# 176 This is python programming
#
# 177 This is python programming
#
# 178 This is python programming
#
# 179 This is python programming
#
# 180 This is python programming
#
# 181 This is python programming
#
# 182 This is python programming
#
# 183 This is python programming
#
# 184 This is python programming
#
# 185 This is python programming
#
# 186 This is python programming
#
# 187 This is python programming
#
# 188 This is python programming
#
# 189 This is python programming
#
# 190 This is python programming
#
# 191 This is python programming
#
# 192 This is python programming
#
# 193 This is python programming
#
# 194 This is python programming
#
# 195 This is python programming
#
# 196 This is python programming
#
# 197 This is python programming
#
# 198 This is python programming
#
# 199 This is python programming
#
# 200 This is python programming
#
# 201 This is python programming
#
# 202 This is python programming
#
# 203 This is python programming
#
# 204 This is python programming
#
# 205 This is python programming
#
# 206 This is python programming
#
# 207 This is python programming
#
# 208 This is python programming
#
# 209 This is python programming
#
# 210 This is python programming
#
# 211 This is python programming
#
# 212 This is python programming
#
# 213 This is python programming
#
# 214 This is python programming
#
# 215 This is python programming
#
# 216 This is python programming
#
# 217 This is python programming
#
# 218 This is python programming
#
# 219 This is python programming
#
# 220 This is python programming
#
# 221 This is python programming
#
# 222 This is python programming
#
# 223 This is python programming
#
# 224 This is python programming
#
# 225 This is python programming
#
# 226 This is python programming
#
# 227 This is python programming
#
# 228 This is python programming
#
# 229 This is python programming
#
# 230 This is python programming
#
# 231 This is python programming
#
# 232 This is python programming
#
# 233 This is python programming
#
# 234 This is python programming
#
# 235 This is python programming
#
# 236 This is python programming
#
# 237 This is python programming
#
# 238 This is python programming
#
# 239 This is python programming
#
# 240 This is python programming
#
# 241 This is python programming
#
# 242 This is python programming
#
# 243 This is python programming
#
# 244 This is python programming
#
# 245 This is python programming
#
# 246 This is python programming
#
# 247 This is python programming
#
# 248 This is python programming
#
# 249 This is python programming
#
# 250 This is python programming
#
# Press 1 : if you want to print next 250 lines
# press 2 : if you want to quit
# Enter your choice 1
# 252 This is python programming
#
# 253 This is python programming
#
# 254 This is python programming
#
# 255 This is python programming
#
# 256 This is python programming
#
# 257 This is python programming
#
# 258 This is python programming
#
# 259 This is python programming
#
# 260 This is python programming
#
# 261 This is python programming
#
# 262 This is python programming
#
# 263 This is python programming
#
# 264 This is python programming
#
# 265 This is python programming
#
# 266 This is python programming
#
# 267 This is python programming
#
# 268 This is python programming
#
# 269 This is python programming
#
# 270 This is python programming
#
# 271 This is python programming
#
# 272 This is python programming
#
# 273 This is python programming
#
# 274 This is python programming
#
# 275 This is python programming
#
# 276 This is python programming
#
# 277 This is python programming
#
# 278 This is python programming
#
# 279 This is python programming
#
# 280 This is python programming
#
# 281 This is python programming
#
# 282 This is python programming
#
# 283 This is python programming
#
# 284 This is python programming
#
# 285 This is python programming
#
# 286 This is python programming
#
# 287 This is python programming
#
# 288 This is python programming
#
# 289 This is python programming
#
# 290 This is python programming
#
# 291 This is python programming
#
# 292 This is python programming
#
# 293 This is python programming
#
# 294 This is python programming
#
# 295 This is python programming
#
# 296 This is python programming
#
# 297 This is python programming
#
# 298 This is python programming
#
# 299 This is python programming
#
# 300 This is python programming
#
# 301 This is python programming
#
# 302 This is python programming
#
# 303 This is python programming
#
# 304 This is python programming
#
# 305 This is python programming
#
# 306 This is python programming
#
# 307 This is python programming
#
# 308 This is python programming
#
# 309 This is python programming
#
# 310 This is python programming
#
# 311 This is python programming
#
# 312 This is python programming
#
# 313 This is python programming
#
# 314 This is python programming
#
# 315 This is python programming
#
# 316 This is python programming
#
# 317 This is python programming
#
# 318 This is python programming
#
# 319 This is python programming
#
# 320 This is python programming
#
# 321 This is python programming
#
# 322 This is python programming
#
# 323 This is python programming
#
# 324 This is python programming
#
# 325 This is python programming
#
# 326 This is python programming
#
# 327 This is python programming
#
# 328 This is python programming
#
# 329 This is python programming
#
# 330 This is python programming
#
# 331 This is python programming
#
# 332 This is python programming
#
# 333 This is python programming
#
# 334 This is python programming
#
# 335 This is python programming
#
# 336 This is python programming
#
# 337 This is python programming
#
# 338 This is python programming
#
# 339 This is python programming
#
# 340 This is python programming
#
# 341 This is python programming
#
# 342 This is python programming
#
# 343 This is python programming
#
# 344 This is python programming
#
# 345 This is python programming
#
# 346 This is python programming
#
# 347 This is python programming
#
# 348 This is python programming
#
# 349 This is python programming
#
# 350 This is python programming
#
# 351 This is python programming
#
# 352 This is python programming
#
# 353 This is python programming
#
# 354 This is python programming
#
# 355 This is python programming
#
# 356 This is python programming
#
# 357 This is python programming
#
# 358 This is python programming
#
# 359 This is python programming
#
# 360 This is python programming
#
# 361 This is python programming
#
# 362 This is python programming
#
# 363 This is python programming
#
# 364 This is python programming
#
# 365 This is python programming
#
# 366 This is python programming
#
# 367 This is python programming
#
# 368 This is python programming
#
# 369 This is python programming
#
# 370 This is python programming
#
# 371 This is python programming
#
# 372 This is python programming
#
# 373 This is python programming
#
# 374 This is python programming
#
# 375 This is python programming
#
# 376 This is python programming
#
# 377 This is python programming
#
# 378 This is python programming
#
# 379 This is python programming
#
# 380 This is python programming
#
# 381 This is python programming
#
# 382 This is python programming
#
# 383 This is python programming
#
# 384 This is python programming
#
# 385 This is python programming
#
# 386 This is python programming
#
# 387 This is python programming
#
# 388 This is python programming
#
# 389 This is python programming
#
# 390 This is python programming
#
# 391 This is python programming
#
# 392 This is python programming
#
# 393 This is python programming
#
# 394 This is python programming
#
# 395 This is python programming
#
# 396 This is python programming
#
# 397 This is python programming
#
# 398 This is python programming
#
# 399 This is python programming
#
# 400 This is python programming
#
# 401 This is python programming
#
# 402 This is python programming
#
# 403 This is python programming
#
# 404 This is python programming
#
# 405 This is python programming
#
# 406 This is python programming
#
# 407 This is python programming
#
# 408 This is python programming
#
# 409 This is python programming
#
# 410 This is python programming
#
# 411 This is python programming
#
# 412 This is python programming
#
# 413 This is python programming
#
# 414 This is python programming
#
# 415 This is python programming
#
# 416 This is python programming
#
# 417 This is python programming
#
# 418 This is python programming
#
# 419 This is python programming
#
# 420 This is python programming
#
# 421 This is python programming
#
# 422 This is python programming
#
# 423 This is python programming
#
# 424 This is python programming
#
# 425 This is python programming
#
# 426 This is python programming
#
# 427 This is python programming
#
# 428 This is python programming
#
# 429 This is python programming
#
# 430 This is python programming
#
# 431 This is python programming
#
# 432 This is python programming
#
# 433 This is python programming
#
# 434 This is python programming
#
# 435 This is python programming
#
# 436 This is python programming
#
# 437 This is python programming
#
# 438 This is python programming
#
# 439 This is python programming
#
# 440 This is python programming
#
# 441 This is python programming
#
# 442 This is python programming
#
# 443 This is python programming
#
# 444 This is python programming
#
# 445 This is python programming
#
# 446 This is python programming
#
# 447 This is python programming
#
# 448 This is python programming
#
# 449 This is python programming
#
# 450 This is python programming
#
# 451 This is python programming
#
# 452 This is python programming
#
# 453 This is python programming
#
# 454 This is python programming
#
# 455 This is python programming
#
# 456 This is python programming
#
# 457 This is python programming
#
# 458 This is python programming
#
# 459 This is python programming
#
# 460 This is python programming
#
# 461 This is python programming
#
# 462 This is python programming
#
# 463 This is python programming
#
# 464 This is python programming
#
# 465 This is python programming
#
# 466 This is python programming
#
# 467 This is python programming
#
# 468 This is python programming
#
# 469 This is python programming
#
# 470 This is python programming
#
# 471 This is python programming
#
# 472 This is python programming
#
# 473 This is python programming
#
# 474 This is python programming
#
# 475 This is python programming
#
# 476 This is python programming
#
# 477 This is python programming
#
# 478 This is python programming
#
# 479 This is python programming
#
# 480 This is python programming
#
# 481 This is python programming
#
# 482 This is python programming
#
# 483 This is python programming
#
# 484 This is python programming
#
# 485 This is python programming
#
# 486 This is python programming
#
# 487 This is python programming
#
# 488 This is python programming
#
# 489 This is python programming
#
# 490 This is python programming
#
# 491 This is python programming
#
# 492 This is python programming
#
# 493 This is python programming
#
# 494 This is python programming
#
# 495 This is python programming
#
# 496 This is python programming
#
# 497 This is python programming
#
# 498 This is python programming
#
# 499 This is python programming
#
# 500 This is python programming
#
# 501 This is python programming
#
# Press 1 : if you want to print next 250 lines
# press 2 : if you want to quit
# Enter your choice 1
# 503 This is python programming
#
# 504 This is python programming
#
# 505 This is python programming
#
# 506 This is python programming
#
# 507 This is python programming
#
# 508 This is python programming
#
# 509 This is python programming
#
# 510 This is python programming
#
# 511 This is python programming
#
# 512 This is python programming
#
# 513 This is python programming
#
# 514 This is python programming
#
# 515 This is python programming
#
# 516 This is python programming
#
# 517 This is python programming
#
# 518 This is python programming
#
# 519 This is python programming
#
# 520 This is python programming
#
# 521 This is python programming
#
# 522 This is python programming
#
# 523 This is python programming
#
# 524 This is python programming
#
# 525 This is python programming
#
# 526 This is python programming
#
# 527 This is python programming
#
# 528 This is python programming
#
# 529 This is python programming
#
# 530 This is python programming
#
# 531 This is python programming
#
# 532 This is python programming
#
# 533 This is python programming
#
# 534 This is python programming
#
# 535 This is python programming
#
# 536 This is python programming
#
# 537 This is python programming
#
# 538 This is python programming
#
# 539 This is python programming
#
# 540 This is python programming
#
# 541 This is python programming
#
# 542 This is python programming
#
# 543 This is python programming
#
# 544 This is python programming
#
# 545 This is python programming
#
# 546 This is python programming
#
# 547 This is python programming
#
# 548 This is python programming
#
# 549 This is python programming
#
# 550 This is python programming
#
# 551 This is python programming
#
# 552 This is python programming
#
# 553 This is python programming
#
# 554 This is python programming
#
# 555 This is python programming
#
# 556 This is python programming
#
# 557 This is python programming
#
# 558 This is python programming
#
# 559 This is python programming
#
# 560 This is python programming
#
# 561 This is python programming
#
# 562 This is python programming
#
# 563 This is python programming
#
# 564 This is python programming
#
# 565 This is python programming
#
# 566 This is python programming
#
# 567 This is python programming
#
# 568 This is python programming
#
# 569 This is python programming
#
# 570 This is python programming
#
# 571 This is python programming
#
# 572 This is python programming
#
# 573 This is python programming
#
# 574 This is python programming
#
# 575 This is python programming
#
# 576 This is python programming
#
# 577 This is python programming
#
# 578 This is python programming
#
# 579 This is python programming
#
# 580 This is python programming
#
# 581 This is python programming
#
# 582 This is python programming
#
# 583 This is python programming
#
# 584 This is python programming
#
# 585 This is python programming
#
# 586 This is python programming
#
# 587 This is python programming
#
# 588 This is python programming
#
# 589 This is python programming
#
# 590 This is python programming
#
# 591 This is python programming
#
# 592 This is python programming
#
# 593 This is python programming
#
# 594 This is python programming
#
# 595 This is python programming
#
# 596 This is python programming
#
# 597 This is python programming
#
# 598 This is python programming
#
# 599 This is python programming
#
# 600 This is python programming
#
# 601 This is python programming
#
# 602 This is python programming
#
# 603 This is python programming
#
# 604 This is python programming
#
# 605 This is python programming
#
# 606 This is python programming
#
# 607 This is python programming
#
# 608 This is python programming
#
# 609 This is python programming
#
# 610 This is python programming
#
# 611 This is python programming
#
# 612 This is python programming
#
# 613 This is python programming
#
# 614 This is python programming
#
# 615 This is python programming
#
# 616 This is python programming
#
# 617 This is python programming
#
# 618 This is python programming
#
# 619 This is python programming
#
# 620 This is python programming
#
# 621 This is python programming
#
# 622 This is python programming
#
# 623 This is python programming
#
# 624 This is python programming
#
# 625 This is python programming
#
# 626 This is python programming
#
# 627 This is python programming
#
# 628 This is python programming
#
# 629 This is python programming
#
# 630 This is python programming
#
# 631 This is python programming
#
# 632 This is python programming
#
# 633 This is python programming
#
# 634 This is python programming
#
# 635 This is python programming
#
# 636 This is python programming
#
# 637 This is python programming
#
# 638 This is python programming
#
# 639 This is python programming
#
# 640 This is python programming
#
# 641 This is python programming
#
# 642 This is python programming
#
# 643 This is python programming
#
# 644 This is python programming
#
# 645 This is python programming
#
# 646 This is python programming
#
# 647 This is python programming
#
# 648 This is python programming
#
# 649 This is python programming
#
# 650 This is python programming
#
# 651 This is python programming
#
# 652 This is python programming
#
# 653 This is python programming
#
# 654 This is python programming
#
# 655 This is python programming
#
# 656 This is python programming
#
# 657 This is python programming
#
# 658 This is python programming
#
# 659 This is python programming
#
# 660 This is python programming
#
# 661 This is python programming
#
# 662 This is python programming
#
# 663 This is python programming
#
# 664 This is python programming
#
# 665 This is python programming
#
# 666 This is python programming
#
# 667 This is python programming
#
# 668 This is python programming
#
# 669 This is python programming
#
# 670 This is python programming
#
# 671 This is python programming
#
# 672 This is python programming
#
# 673 This is python programming
#
# 674 This is python programming
#
# 675 This is python programming
#
# 676 This is python programming
#
# 677 This is python programming
#
# 678 This is python programming
#
# 679 This is python programming
#
# 680 This is python programming
#
# 681 This is python programming
#
# 682 This is python programming
#
# 683 This is python programming
#
# 684 This is python programming
#
# 685 This is python programming
#
# 686 This is python programming
#
# 687 This is python programming
#
# 688 This is python programming
#
# 689 This is python programming
#
# 690 This is python programming
#
# 691 This is python programming
#
# 692 This is python programming
#
# 693 This is python programming
#
# 694 This is python programming
#
# 695 This is python programming
#
# 696 This is python programming
#
# 697 This is python programming
#
# 698 This is python programming
#
# 699 This is python programming
#
# 700 This is python programming
#
# 701 This is python programming
#
# 702 This is python programming
#
# 703 This is python programming
#
# 704 This is python programming
#
# 705 This is python programming
#
# 706 This is python programming
#
# 707 This is python programming
#
# 708 This is python programming
#
# 709 This is python programming
#
# 710 This is python programming
#
# 711 This is python programming
#
# 712 This is python programming
#
# 713 This is python programming
#
# 714 This is python programming
#
# 715 This is python programming
#
# 716 This is python programming
#
# 717 This is python programming
#
# 718 This is python programming
#
# 719 This is python programming
#
# 720 This is python programming
#
# 721 This is python programming
#
# 722 This is python programming
#
# 723 This is python programming
#
# 724 This is python programming
#
# 725 This is python programming
#
# 726 This is python programming
#
# 727 This is python programming
#
# 728 This is python programming
#
# 729 This is python programming
#
# 730 This is python programming
#
# 731 This is python programming
#
# 732 This is python programming
#
# 733 This is python programming
#
# 734 This is python programming
#
# 735 This is python programming
#
# 736 This is python programming
#
# 737 This is python programming
#
# 738 This is python programming
#
# 739 This is python programming
#
# 740 This is python programming
#
# 741 This is python programming
#
# 742 This is python programming
#
# 743 This is python programming
#
# 744 This is python programming
#
# 745 This is python programming
#
# 746 This is python programming
#
# 747 This is python programming
#
# 748 This is python programming
#
# 749 This is python programming
#
# 750 This is python programming
#
# 751 This is python programming
#
# 752 This is python programming
#
# Press 1 : if you want to print next 250 lines
# press 2 : if you want to quit
# Enter your choice 1
# 754 This is python programming
#
# 755 This is python programming
#
# 756 This is python programming
#
# 757 This is python programming
#
# 758 This is python programming
#
# 759 This is python programming
#
# 760 This is python programming
#
# 761 This is python programming
#
# 762 This is python programming
#
# 763 This is python programming
#
# 764 This is python programming
#
# 765 This is python programming
#
# 766 This is python programming
#
# 767 This is python programming
#
# 768 This is python programming
#
# 769 This is python programming
#
# 770 This is python programming
#
# 771 This is python programming
#
# 772 This is python programming
#
# 773 This is python programming
#
# 774 This is python programming
#
# 775 This is python programming
#
# 776 This is python programming
#
# 777 This is python programming
#
# 778 This is python programming
#
# 779 This is python programming
#
# 780 This is python programming
#
# 781 This is python programming
#
# 782 This is python programming
#
# 783 This is python programming
#
# 784 This is python programming
#
# 785 This is python programming
#
# 786 This is python programming
#
# 787 This is python programming
#
# 788 This is python programming
#
# 789 This is python programming
#
# 790 This is python programming
#
# 791 This is python programming
#
# 792 This is python programming
#
# 793 This is python programming
#
# 794 This is python programming
#
# 795 This is python programming
#
# 796 This is python programming
#
# 797 This is python programming
#
# 798 This is python programming
#
# 799 This is python programming
#
# 800 This is python programming
#
# 801 This is python programming
#
# 802 This is python programming
#
# 803 This is python programming
#
# 804 This is python programming
#
# 805 This is python programming
#
# 806 This is python programming
#
# 807 This is python programming
#
# 808 This is python programming
#
# 809 This is python programming
#
# 810 This is python programming
#
# 811 This is python programming
#
# 812 This is python programming
#
# 813 This is python programming
#
# 814 This is python programming
#
# 815 This is python programming
#
# 816 This is python programming
#
# 817 This is python programming
#
# 818 This is python programming
#
# 819 This is python programming
#
# 820 This is python programming
#
# 821 This is python programming
#
# 822 This is python programming
#
# 823 This is python programming
#
# 824 This is python programming
#
# 825 This is python programming
#
# 826 This is python programming
#
# 827 This is python programming
#
# 828 This is python programming
#
# 829 This is python programming
#
# 830 This is python programming
#
# 831 This is python programming
#
# 832 This is python programming
#
# 833 This is python programming
#
# 834 This is python programming
#
# 835 This is python programming
#
# 836 This is python programming
#
# 837 This is python programming
#
# 838 This is python programming
#
# 839 This is python programming
#
# 840 This is python programming
#
# 841 This is python programming
#
# 842 This is python programming
#
# 843 This is python programming
#
# 844 This is python programming
#
# 845 This is python programming
#
# 846 This is python programming
#
# 847 This is python programming
#
# 848 This is python programming
#
# 849 This is python programming
#
# 850 This is python programming
#
# 851 This is python programming
#
# 852 This is python programming
#
# 853 This is python programming
#
# 854 This is python programming
#
# 855 This is python programming
#
# 856 This is python programming
#
# 857 This is python programming
#
# 858 This is python programming
#
# 859 This is python programming
#
# 860 This is python programming
#
# 861 This is python programming
#
# 862 This is python programming
#
# 863 This is python programming
#
# 864 This is python programming
#
# 865 This is python programming
#
# 866 This is python programming
#
# 867 This is python programming
#
# 868 This is python programming
#
# 869 This is python programming
#
# 870 This is python programming
#
# 871 This is python programming
#
# 872 This is python programming
#
# 873 This is python programming
#
# 874 This is python programming
#
# 875 This is python programming
#
# 876 This is python programming
#
# 877 This is python programming
#
# 878 This is python programming
#
# 879 This is python programming
#
# 880 This is python programming
#
# 881 This is python programming
#
# 882 This is python programming
#
# 883 This is python programming
#
# 884 This is python programming
#
# 885 This is python programming
#
# 886 This is python programming
#
# 887 This is python programming
#
# 888 This is python programming
#
# 889 This is python programming
#
# 890 This is python programming
#
# 891 This is python programming
#
# 892 This is python programming
#
# 893 This is python programming
#
# 894 This is python programming
#
# 895 This is python programming
#
# 896 This is python programming
#
# 897 This is python programming
#
# 898 This is python programming
#
# 899 This is python programming
#
# 900 This is python programming
#
# 901 This is python programming
#
# 902 This is python programming
#
# 903 This is python programming
#
# 904 This is python programming
#
# 905 This is python programming
#
# 906 This is python programming
#
# 907 This is python programming
#
# 908 This is python programming
#
# 909 This is python programming
#
# 910 This is python programming
#
# 911 This is python programming
#
# 912 This is python programming
#
# 913 This is python programming
#
# 914 This is python programming
#
# 915 This is python programming
#
# 916 This is python programming
#
# 917 This is python programming
#
# 918 This is python programming
#
# 919 This is python programming
#
# 920 This is python programming
#
# 921 This is python programming
#
# 922 This is python programming
#
# 923 This is python programming
#
# 924 This is python programming
#
# 925 This is python programming
#
# 926 This is python programming
#
# 927 This is python programming
#
# 928 This is python programming
#
# 929 This is python programming
#
# 930 This is python programming
#
# 931 This is python programming
#
# 932 This is python programming
#
# 933 This is python programming
#
# 934 This is python programming
#
# 935 This is python programming
#
# 936 This is python programming
#
# 937 This is python programming
#
# 938 This is python programming
#
# 939 This is python programming
#
# 940 This is python programming
#
# 941 This is python programming
#
# 942 This is python programming
#
# 943 This is python programming
#
# 944 This is python programming
#
# 945 This is python programming
#
# 946 This is python programming
#
# 947 This is python programming
#
# 948 This is python programming
#
# 949 This is python programming
#
# 950 This is python programming
#
# 951 This is python programming
#
# 952 This is python programming
#
# 953 This is python programming
#
# 954 This is python programming
#
# 955 This is python programming
#
# 956 This is python programming
#
# 957 This is python programming
#
# 958 This is python programming
#
# 959 This is python programming
#
# 960 This is python programming
#
# 961 This is python programming
#
# 962 This is python programming
#
# 963 This is python programming
#
# 964 This is python programming
#
# 965 This is python programming
#
# 966 This is python programming
#
# 967 This is python programming
#
# 968 This is python programming
#
# 969 This is python programming
#
# 970 This is python programming
#
# 971 This is python programming
#
# 972 This is python programming
#
# 973 This is python programming
#
# 974 This is python programming
#
# 975 This is python programming
#
# 976 This is python programming
#
# 977 This is python programming
#
# 978 This is python programming
#
# 979 This is python programming
#
# 980 This is python programming
#
# 981 This is python programming
#
# 982 This is python programming
#
# 983 This is python programming
#
# 984 This is python programming
#
# 985 This is python programming
#
# 986 This is python programming
#
# 987 This is python programming
#
# 988 This is python programming
#
# 989 This is python programming
#
# 990 This is python programming
#
# 991 This is python programming
#
# 992 This is python programming
#
# 993 This is python programming
#
# 994 This is python programming
#
# 995 This is python programming
#
# 996 This is python programming
#
# 997 This is python programming
#
# 998 This is python programming
#
# 999 This is python programming
#
# 1000 This is python programming
#
#
#
# Press 1 : if you want to print next 250 lines
# press 2 : if you want to quit
# Enter your choice 1
# File is empty
