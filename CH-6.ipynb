# %% [markdown]
# Working With Files

# %%
import sys

# %%
sys.version

# %%
f = open('abc.txt','w')

# %%
f.write("HP")

# %%
f.close()

# %%
f = open('abc.txt','w')
f.write("")
f.close()

# %%
f=open("file1.txt",'w')
f.write("Hello world\n")
f.write("I'm your Laptop LOQ")
f.close()

# %%
f=open("file2.txt",'w')
f.writelines("Hello world\n\n")
f.writelines("I'm your Laptop LOQ")
f.close()

# %%
F=open("file1.txt")
F.read()

# %%
F.read()

# %%
F.seek(0)

# %%
F.read()

# %%
F.tell()

# %%
f=open("file3.txt",'w')
f.write("python\n")
f.write("programming")
F.close()

# %%
f=open("file3.txt")
f.read(4)
f.read(4)

# %%
f.seek(0)
f.read()

# %%
f.tell()

# %%
f=open("abc.txt")
f.read(4)
print(f.tell())
f.read(4)

# %%
f.seek(0)

# %%
print(f.readline(19))
print(f.readline(-1))

# %%
print(f.readlines())

# %%
f=open("file5.txt",'w')
f.write("This is \n")
f.write("Pyhton Programming")
f.close()

# %%
f=open("file5.txt")
content=f.read()

# %%
for i in content:
    print(i,end="")

# %%
# WAP To find total number of vowels in given file
count=0
for i in content:
    if i in ('a','e','i','o','u','A','E','I','O','U'):
        count+=1
print(f"{count} is total number of vowels")

# %%
f.seek(0)

# %%
print(f.read().split())

# %%
# WAP TO find total number if vowels total characters total words from the given file
F=open("alice_in_wonderland.txt")
content=F.read()
count=0
count_vowels=0
count_consonants=0
count_punct=0
for i in content:
    if i in ('a','e','i','o','u','A','E','I','O','U'):
        count_vowels+=1
    elif i.isalpha()==True or not ('a','e','i','o','u','A','E','I','O','U'):
        count_consonants+=1
    else:
        count_punct+=1
F.seek(0)
print(f"{len(F.read().split())} is total number of words")
print(f"{count_vowels} is total number of vowels")
print(f"{count_consonants} is total number of consonants")
print(f"{count_punct} is total numbers of space and punctuation")

# %%
F.seek(0)

# %%
#WAP 
A=open("File6.txt",'w')
for i in range(4):
    A.write(f"This is line {i+1}\n")
A.write(f"This is line {i+2}")
A.close()
print("File has been created and String has been inserted")

# %%
# WAP to create a file named big.txt that contains 1000 lines having this is phython pogramming thousands times using only list comprehention
Big=open("big.txt")
for i in Big.readlines():
    print(i.split()[0])

# %%
F1=open("big.txt")
F2=open("file8.txt",'w')
count=1
for i in F1:
    F2.write(str(count)+' : '+i)
    count+=1
F2.close()

# %%
# WAP print in reverse
F1=open("Big.txt")
F2=open("file9.txt",'w')
STR=""
F=F1.readlines()
F1.seek(0)
count=1
print(F)
for i in F1:
    for j in F:
        j[::-1]
    if count==5:
        break
    F2.write(str(count)+" : "+str(count)+" "+j[::-1]+"\n")
    count+=1
F2.write(str(count)+" : "+str(count)+" "+j[::-1])
F2.close()

# %%
F1=open("Big.txt")
F2=open("file10.txt",'w')
STR=""
F=F1.readlines()
F1.seek(0)
count=1
for i in F1:
    for j in F:
        A=[lambda K: F2.write(i.split()[::-1]) for i in F1.readlines()]
    if count==5:
        break
    F2.write(str(count)+" : "+A[count]+"\n")
    count+=1
F2.write(str(count)+" : "+A[count+2])
F2.close()

# %%
F1=open("file10.txt")
A=list()
for i in F1.readlines():
    for k in i:
        if k=='g':
            print('y',end="")
        else:
            print(k,end="")

# %%
F=open("big.txt")
F.seek(99999999999)
F.readline()

# %%
#wap such that your solution asked for prompt to give file name and display the text file (only the first 25 lines) it should prompt the use to print
#to print next 25 lines or to quit
k=True
count=0
F=open(input("Enter name of the File"))
while(k):
    oldcount=count
    count+=250
    for i in range(oldcount,count):
        print(F.readline())
    print('Press 1 : if you want to print next 250 lines')
    print("press 2 : if you want to quit")
    Input=int(input("Enter your choice"))
    if Input==2:
        k=False
    if F.readline()=="":
        print("File is empty")
        k=False

# %%
L=['Hi','Hello','ABC']
for i,j in enumerate(L,1):
    print(i,j)

# %%
f=open(input("Enter file name : "))
num_lines=int(input("Enter the number of lines to display"))
for index,line in enumerate(f,1):
    print(index," : ",line)
    if index%num_lines==0:
        x=input("Hit any key to continue or 'q' to quit : ")
        if x.lower()=='q':
            print("\nList has been ended")
            break
f.close()
# Out:
# Enter file name :  big.txt
# Enter the number of lines to display 254
# 1  :  1 This is python programming
#
# 2  :  2 This is python programming
#
# 3  :  3 This is python programming
#
# 4  :  4 This is python programming
#
# 5  :  5 This is python programming
#
# 6  :  6 This is python programming
#
# 7  :  7 This is python programming
#
# 8  :  8 This is python programming
#
# 9  :  9 This is python programming
#
# 10  :  10 This is python programming
#
# 11  :  11 This is python programming
#
# 12  :  12 This is python programming
#
# 13  :  13 This is python programming
#
# 14  :  14 This is python programming
#
# 15  :  15 This is python programming
#
# 16  :  16 This is python programming
#
# 17  :  17 This is python programming
#
# 18  :  18 This is python programming
#
# 19  :  19 This is python programming
#
# 20  :  20 This is python programming
#
# 21  :  21 This is python programming
#
# 22  :  22 This is python programming
#
# 23  :  23 This is python programming
#
# 24  :  24 This is python programming
#
# 25  :  25 This is python programming
#
# 26  :  26 This is python programming
#
# 27  :  27 This is python programming
#
# 28  :  28 This is python programming
#
# 29  :  29 This is python programming
#
# 30  :  30 This is python programming
#
# 31  :  31 This is python programming
#
# 32  :  32 This is python programming
#
# 33  :  33 This is python programming
#
# 34  :  34 This is python programming
#
# 35  :  35 This is python programming
#
# 36  :  36 This is python programming
#
# 37  :  37 This is python programming
#
# 38  :  38 This is python programming
#
# 39  :  39 This is python programming
#
# 40  :  40 This is python programming
#
# 41  :  41 This is python programming
#
# 42  :  42 This is python programming
#
# 43  :  43 This is python programming
#
# 44  :  44 This is python programming
#
# 45  :  45 This is python programming
#
# 46  :  46 This is python programming
#
# 47  :  47 This is python programming
#
# 48  :  48 This is python programming
#
# 49  :  49 This is python programming
#
# 50  :  50 This is python programming
#
# 51  :  51 This is python programming
#
# 52  :  52 This is python programming
#
# 53  :  53 This is python programming
#
# 54  :  54 This is python programming
#
# 55  :  55 This is python programming
#
# 56  :  56 This is python programming
#
# 57  :  57 This is python programming
#
# 58  :  58 This is python programming
#
# 59  :  59 This is python programming
#
# 60  :  60 This is python programming
#
# 61  :  61 This is python programming
#
# 62  :  62 This is python programming
#
# 63  :  63 This is python programming
#
# 64  :  64 This is python programming
#
# 65  :  65 This is python programming
#
# 66  :  66 This is python programming
#
# 67  :  67 This is python programming
#
# 68  :  68 This is python programming
#
# 69  :  69 This is python programming
#
# 70  :  70 This is python programming
#
# 71  :  71 This is python programming
#
# 72  :  72 This is python programming
#
# 73  :  73 This is python programming
#
# 74  :  74 This is python programming
#
# 75  :  75 This is python programming
#
# 76  :  76 This is python programming
#
# 77  :  77 This is python programming
#
# 78  :  78 This is python programming
#
# 79  :  79 This is python programming
#
# 80  :  80 This is python programming
#
# 81  :  81 This is python programming
#
# 82  :  82 This is python programming
#
# 83  :  83 This is python programming
#
# 84  :  84 This is python programming
#
# 85  :  85 This is python programming
#
# 86  :  86 This is python programming
#
# 87  :  87 This is python programming
#
# 88  :  88 This is python programming
#
# 89  :  89 This is python programming
#
# 90  :  90 This is python programming
#
# 91  :  91 This is python programming
#
# 92  :  92 This is python programming
#
# 93  :  93 This is python programming
#
# 94  :  94 This is python programming
#
# 95  :  95 This is python programming
#
# 96  :  96 This is python programming
#
# 97  :  97 This is python programming
#
# 98  :  98 This is python programming
#
# 99  :  99 This is python programming
#
# 100  :  100 This is python programming
#
# 101  :  101 This is python programming
#
# 102  :  102 This is python programming
#
# 103  :  103 This is python programming
#
# 104  :  104 This is python programming
#
# 105  :  105 This is python programming
#
# 106  :  106 This is python programming
#
# 107  :  107 This is python programming
#
# 108  :  108 This is python programming
#
# 109  :  109 This is python programming
#
# 110  :  110 This is python programming
#
# 111  :  111 This is python programming
#
# 112  :  112 This is python programming
#
# 113  :  113 This is python programming
#
# 114  :  114 This is python programming
#
# 115  :  115 This is python programming
#
# 116  :  116 This is python programming
#
# 117  :  117 This is python programming
#
# 118  :  118 This is python programming
#
# 119  :  119 This is python programming
#
# 120  :  120 This is python programming
#
# 121  :  121 This is python programming
#
# 122  :  122 This is python programming
#
# 123  :  123 This is python programming
#
# 124  :  124 This is python programming
#
# 125  :  125 This is python programming
#
# 126  :  126 This is python programming
#
# 127  :  127 This is python programming
#
# 128  :  128 This is python programming
#
# 129  :  129 This is python programming
#
# 130  :  130 This is python programming
#
# 131  :  131 This is python programming
#
# 132  :  132 This is python programming
#
# 133  :  133 This is python programming
#
# 134  :  134 This is python programming
#
# 135  :  135 This is python programming
#
# 136  :  136 This is python programming
#
# 137  :  137 This is python programming
#
# 138  :  138 This is python programming
#
# 139  :  139 This is python programming
#
# 140  :  140 This is python programming
#
# 141  :  141 This is python programming
#
# 142  :  142 This is python programming
#
# 143  :  143 This is python programming
#
# 144  :  144 This is python programming
#
# 145  :  145 This is python programming
#
# 146  :  146 This is python programming
#
# 147  :  147 This is python programming
#
# 148  :  148 This is python programming
#
# 149  :  149 This is python programming
#
# 150  :  150 This is python programming
#
# 151  :  151 This is python programming
#
# 152  :  152 This is python programming
#
# 153  :  153 This is python programming
#
# 154  :  154 This is python programming
#
# 155  :  155 This is python programming
#
# 156  :  156 This is python programming
#
# 157  :  157 This is python programming
#
# 158  :  158 This is python programming
#
# 159  :  159 This is python programming
#
# 160  :  160 This is python programming
#
# 161  :  161 This is python programming
#
# 162  :  162 This is python programming
#
# 163  :  163 This is python programming
#
# 164  :  164 This is python programming
#
# 165  :  165 This is python programming
#
# 166  :  166 This is python programming
#
# 167  :  167 This is python programming
#
# 168  :  168 This is python programming
#
# 169  :  169 This is python programming
#
# 170  :  170 This is python programming
#
# 171  :  171 This is python programming
#
# 172  :  172 This is python programming
#
# 173  :  173 This is python programming
#
# 174  :  174 This is python programming
#
# 175  :  175 This is python programming
#
# 176  :  176 This is python programming
#
# 177  :  177 This is python programming
#
# 178  :  178 This is python programming
#
# 179  :  179 This is python programming
#
# 180  :  180 This is python programming
#
# 181  :  181 This is python programming
#
# 182  :  182 This is python programming
#
# 183  :  183 This is python programming
#
# 184  :  184 This is python programming
#
# 185  :  185 This is python programming
#
# 186  :  186 This is python programming
#
# 187  :  187 This is python programming
#
# 188  :  188 This is python programming
#
# 189  :  189 This is python programming
#
# 190  :  190 This is python programming
#
# 191  :  191 This is python programming
#
# 192  :  192 This is python programming
#
# 193  :  193 This is python programming
#
# 194  :  194 This is python programming
#
# 195  :  195 This is python programming
#
# 196  :  196 This is python programming
#
# 197  :  197 This is python programming
#
# 198  :  198 This is python programming
#
# 199  :  199 This is python programming
#
# 200  :  200 This is python programming
#
# 201  :  201 This is python programming
#
# 202  :  202 This is python programming
#
# 203  :  203 This is python programming
#
# 204  :  204 This is python programming
#
# 205  :  205 This is python programming
#
# 206  :  206 This is python programming
#
# 207  :  207 This is python programming
#
# 208  :  208 This is python programming
#
# 209  :  209 This is python programming
#
# 210  :  210 This is python programming
#
# 211  :  211 This is python programming
#
# 212  :  212 This is python programming
#
# 213  :  213 This is python programming
#
# 214  :  214 This is python programming
#
# 215  :  215 This is python programming
#
# 216  :  216 This is python programming
#
# 217  :  217 This is python programming
#
# 218  :  218 This is python programming
#
# 219  :  219 This is python programming
#
# 220  :  220 This is python programming
#
# 221  :  221 This is python programming
#
# 222  :  222 This is python programming
#
# 223  :  223 This is python programming
#
# 224  :  224 This is python programming
#
# 225  :  225 This is python programming
#
# 226  :  226 This is python programming
#
# 227  :  227 This is python programming
#
# 228  :  228 This is python programming
#
# 229  :  229 This is python programming
#
# 230  :  230 This is python programming
#
# 231  :  231 This is python programming
#
# 232  :  232 This is python programming
#
# 233  :  233 This is python programming
#
# 234  :  234 This is python programming
#
# 235  :  235 This is python programming
#
# 236  :  236 This is python programming
#
# 237  :  237 This is python programming
#
# 238  :  238 This is python programming
#
# 239  :  239 This is python programming
#
# 240  :  240 This is python programming
#
# 241  :  241 This is python programming
#
# 242  :  242 This is python programming
#
# 243  :  243 This is python programming
#
# 244  :  244 This is python programming
#
# 245  :  245 This is python programming
#
# 246  :  246 This is python programming
#
# 247  :  247 This is python programming
#
# 248  :  248 This is python programming
#
# 249  :  249 This is python programming
#
# 250  :  250 This is python programming
#
# 251  :  251 This is python programming
#
# 252  :  252 This is python programming
#
# 253  :  253 This is python programming
#
# 254  :  254 This is python programming
# Hit any key to continue or 'q' to quit :  e
# 255  :  255 This is python programming
#
# 256  :  256 This is python programming
#
# 257  :  257 This is python programming
#
# 258  :  258 This is python programming
#
# 259  :  259 This is python programming
#
# 260  :  260 This is python programming
#
# 261  :  261 This is python programming
#
# 262  :  262 This is python programming
#
# 263  :  263 This is python programming
#
# 264  :  264 This is python programming
#
# 265  :  265 This is python programming
#
# 266  :  266 This is python programming
#
# 267  :  267 This is python programming
#
# 268  :  268 This is python programming
#
# 269  :  269 This is python programming
#
# 270  :  270 This is python programming
#
# 271  :  271 This is python programming
#
# 272  :  272 This is python programming
#
# 273  :  273 This is python programming
#
# 274  :  274 This is python programming
#
# 275  :  275 This is python programming
#
# 276  :  276 This is python programming
#
# 277  :  277 This is python programming
#
# 278  :  278 This is python programming
#
# 279  :  279 This is python programming
#
# 280  :  280 This is python programming
#
# 281  :  281 This is python programming
#
# 282  :  282 This is python programming
#
# 283  :  283 This is python programming
#
# 284  :  284 This is python programming
#
# 285  :  285 This is python programming
#
# 286  :  286 This is python programming
#
# 287  :  287 This is python programming
#
# 288  :  288 This is python programming
#
# 289  :  289 This is python programming
#
# 290  :  290 This is python programming
#
# 291  :  291 This is python programming
#
# 292  :  292 This is python programming
#
# 293  :  293 This is python programming
#
# 294  :  294 This is python programming
#
# 295  :  295 This is python programming
#
# 296  :  296 This is python programming
#
# 297  :  297 This is python programming
#
# 298  :  298 This is python programming
#
# 299  :  299 This is python programming
#
# 300  :  300 This is python programming
#
# 301  :  301 This is python programming
#
# 302  :  302 This is python programming
#
# 303  :  303 This is python programming
#
# 304  :  304 This is python programming
#
# 305  :  305 This is python programming
#
# 306  :  306 This is python programming
#
# 307  :  307 This is python programming
#
# 308  :  308 This is python programming
#
# 309  :  309 This is python programming
#
# 310  :  310 This is python programming
#
# 311  :  311 This is python programming
#
# 312  :  312 This is python programming
#
# 313  :  313 This is python programming
#
# 314  :  314 This is python programming
#
# 315  :  315 This is python programming
#
# 316  :  316 This is python programming
#
# 317  :  317 This is python programming
#
# 318  :  318 This is python programming
#
# 319  :  319 This is python programming
#
# 320  :  320 This is python programming
#
# 321  :  321 This is python programming
#
# 322  :  322 This is python programming
#
# 323  :  323 This is python programming
#
# 324  :  324 This is python programming
#
# 325  :  325 This is python programming
#
# 326  :  326 This is python programming
#
# 327  :  327 This is python programming
#
# 328  :  328 This is python programming
#
# 329  :  329 This is python programming
#
# 330  :  330 This is python programming
#
# 331  :  331 This is python programming
#
# 332  :  332 This is python programming
#
# 333  :  333 This is python programming
#
# 334  :  334 This is python programming
#
# 335  :  335 This is python programming
#
# 336  :  336 This is python programming
#
# 337  :  337 This is python programming
#
# 338  :  338 This is python programming
#
# 339  :  339 This is python programming
#
# 340  :  340 This is python programming
#
# 341  :  341 This is python programming
#
# 342  :  342 This is python programming
#
# 343  :  343 This is python programming
#
# 344  :  344 This is python programming
#
# 345  :  345 This is python programming
#
# 346  :  346 This is python programming
#
# 347  :  347 This is python programming
#
# 348  :  348 This is python programming
#
# 349  :  349 This is python programming
#
# 350  :  350 This is python programming
#
# 351  :  351 This is python programming
#
# 352  :  352 This is python programming
#
# 353  :  353 This is python programming
#
# 354  :  354 This is python programming
#
# 355  :  355 This is python programming
#
# 356  :  356 This is python programming
#
# 357  :  357 This is python programming
#
# 358  :  358 This is python programming
#
# 359  :  359 This is python programming
#
# 360  :  360 This is python programming
#
# 361  :  361 This is python programming
#
# 362  :  362 This is python programming
#
# 363  :  363 This is python programming
#
# 364  :  364 This is python programming
#
# 365  :  365 This is python programming
#
# 366  :  366 This is python programming
#
# 367  :  367 This is python programming
#
# 368  :  368 This is python programming
#
# 369  :  369 This is python programming
#
# 370  :  370 This is python programming
#
# 371  :  371 This is python programming
#
# 372  :  372 This is python programming
#
# 373  :  373 This is python programming
#
# 374  :  374 This is python programming
#
# 375  :  375 This is python programming
#
# 376  :  376 This is python programming
#
# 377  :  377 This is python programming
#
# 378  :  378 This is python programming
#
# 379  :  379 This is python programming
#
# 380  :  380 This is python programming
#
# 381  :  381 This is python programming
#
# 382  :  382 This is python programming
#
# 383  :  383 This is python programming
#
# 384  :  384 This is python programming
#
# 385  :  385 This is python programming
#
# 386  :  386 This is python programming
#
# 387  :  387 This is python programming
#
# 388  :  388 This is python programming
#
# 389  :  389 This is python programming
#
# 390  :  390 This is python programming
#
# 391  :  391 This is python programming
#
# 392  :  392 This is python programming
#
# 393  :  393 This is python programming
#
# 394  :  394 This is python programming
#
# 395  :  395 This is python programming
#
# 396  :  396 This is python programming
#
# 397  :  397 This is python programming
#
# 398  :  398 This is python programming
#
# 399  :  399 This is python programming
#
# 400  :  400 This is python programming
#
# 401  :  401 This is python programming
#
# 402  :  402 This is python programming
#
# 403  :  403 This is python programming
#
# 404  :  404 This is python programming
#
# 405  :  405 This is python programming
#
# 406  :  406 This is python programming
#
# 407  :  407 This is python programming
#
# 408  :  408 This is python programming
#
# 409  :  409 This is python programming
#
# 410  :  410 This is python programming
#
# 411  :  411 This is python programming
#
# 412  :  412 This is python programming
#
# 413  :  413 This is python programming
#
# 414  :  414 This is python programming
#
# 415  :  415 This is python programming
#
# 416  :  416 This is python programming
#
# 417  :  417 This is python programming
#
# 418  :  418 This is python programming
#
# 419  :  419 This is python programming
#
# 420  :  420 This is python programming
#
# 421  :  421 This is python programming
#
# 422  :  422 This is python programming
#
# 423  :  423 This is python programming
#
# 424  :  424 This is python programming
#
# 425  :  425 This is python programming
#
# 426  :  426 This is python programming
#
# 427  :  427 This is python programming
#
# 428  :  428 This is python programming
#
# 429  :  429 This is python programming
#
# 430  :  430 This is python programming
#
# 431  :  431 This is python programming
#
# 432  :  432 This is python programming
#
# 433  :  433 This is python programming
#
# 434  :  434 This is python programming
#
# 435  :  435 This is python programming
#
# 436  :  436 This is python programming
#
# 437  :  437 This is python programming
#
# 438  :  438 This is python programming
#
# 439  :  439 This is python programming
#
# 440  :  440 This is python programming
#
# 441  :  441 This is python programming
#
# 442  :  442 This is python programming
#
# 443  :  443 This is python programming
#
# 444  :  444 This is python programming
#
# 445  :  445 This is python programming
#
# 446  :  446 This is python programming
#
# 447  :  447 This is python programming
#
# 448  :  448 This is python programming
#
# 449  :  449 This is python programming
#
# 450  :  450 This is python programming
#
# 451  :  451 This is python programming
#
# 452  :  452 This is python programming
#
# 453  :  453 This is python programming
#
# 454  :  454 This is python programming
#
# 455  :  455 This is python programming
#
# 456  :  456 This is python programming
#
# 457  :  457 This is python programming
#
# 458  :  458 This is python programming
#
# 459  :  459 This is python programming
#
# 460  :  460 This is python programming
#
# 461  :  461 This is python programming
#
# 462  :  462 This is python programming
#
# 463  :  463 This is python programming
#
# 464  :  464 This is python programming
#
# 465  :  465 This is python programming
#
# 466  :  466 This is python programming
#
# 467  :  467 This is python programming
#
# 468  :  468 This is python programming
#
# 469  :  469 This is python programming
#
# 470  :  470 This is python programming
#
# 471  :  471 This is python programming
#
# 472  :  472 This is python programming
#
# 473  :  473 This is python programming
#
# 474  :  474 This is python programming
#
# 475  :  475 This is python programming
#
# 476  :  476 This is python programming
#
# 477  :  477 This is python programming
#
# 478  :  478 This is python programming
#
# 479  :  479 This is python programming
#
# 480  :  480 This is python programming
#
# 481  :  481 This is python programming
#
# 482  :  482 This is python programming
#
# 483  :  483 This is python programming
#
# 484  :  484 This is python programming
#
# 485  :  485 This is python programming
#
# 486  :  486 This is python programming
#
# 487  :  487 This is python programming
#
# 488  :  488 This is python programming
#
# 489  :  489 This is python programming
#
# 490  :  490 This is python programming
#
# 491  :  491 This is python programming
#
# 492  :  492 This is python programming
#
# 493  :  493 This is python programming
#
# 494  :  494 This is python programming
#
# 495  :  495 This is python programming
#
# 496  :  496 This is python programming
#
# 497  :  497 This is python programming
#
# 498  :  498 This is python programming
#
# 499  :  499 This is python programming
#
# 500  :  500 This is python programming
#
# 501  :  501 This is python programming
#
# 502  :  502 This is python programming
#
# 503  :  503 This is python programming
#
# 504  :  504 This is python programming
#
# 505  :  505 This is python programming
#
# 506  :  506 This is python programming
#
# 507  :  507 This is python programming
#
# 508  :  508 This is python programming
# Hit any key to continue or 'q' to quit :  s
# 509  :  509 This is python programming
#
# 510  :  510 This is python programming
#
# 511  :  511 This is python programming
#
# 512  :  512 This is python programming
#
# 513  :  513 This is python programming
#
# 514  :  514 This is python programming
#
# 515  :  515 This is python programming
#
# 516  :  516 This is python programming
#
# 517  :  517 This is python programming
#
# 518  :  518 This is python programming
#
# 519  :  519 This is python programming
#
# 520  :  520 This is python programming
#
# 521  :  521 This is python programming
#
# 522  :  522 This is python programming
#
# 523  :  523 This is python programming
#
# 524  :  524 This is python programming
#
# 525  :  525 This is python programming
#
# 526  :  526 This is python programming
#
# 527  :  527 This is python programming
#
# 528  :  528 This is python programming
#
# 529  :  529 This is python programming
#
# 530  :  530 This is python programming
#
# 531  :  531 This is python programming
#
# 532  :  532 This is python programming
#
# 533  :  533 This is python programming
#
# 534  :  534 This is python programming
#
# 535  :  535 This is python programming
#
# 536  :  536 This is python programming
#
# 537  :  537 This is python programming
#
# 538  :  538 This is python programming
#
# 539  :  539 This is python programming
#
# 540  :  540 This is python programming
#
# 541  :  541 This is python programming
#
# 542  :  542 This is python programming
#
# 543  :  543 This is python programming
#
# 544  :  544 This is python programming
#
# 545  :  545 This is python programming
#
# 546  :  546 This is python programming
#
# 547  :  547 This is python programming
#
# 548  :  548 This is python programming
#
# 549  :  549 This is python programming
#
# 550  :  550 This is python programming
#
# 551  :  551 This is python programming
#
# 552  :  552 This is python programming
#
# 553  :  553 This is python programming
#
# 554  :  554 This is python programming
#
# 555  :  555 This is python programming
#
# 556  :  556 This is python programming
#
# 557  :  557 This is python programming
#
# 558  :  558 This is python programming
#
# 559  :  559 This is python programming
#
# 560  :  560 This is python programming
#
# 561  :  561 This is python programming
#
# 562  :  562 This is python programming
#
# 563  :  563 This is python programming
#
# 564  :  564 This is python programming
#
# 565  :  565 This is python programming
#
# 566  :  566 This is python programming
#
# 567  :  567 This is python programming
#
# 568  :  568 This is python programming
#
# 569  :  569 This is python programming
#
# 570  :  570 This is python programming
#
# 571  :  571 This is python programming
#
# 572  :  572 This is python programming
#
# 573  :  573 This is python programming
#
# 574  :  574 This is python programming
#
# 575  :  575 This is python programming
#
# 576  :  576 This is python programming
#
# 577  :  577 This is python programming
#
# 578  :  578 This is python programming
#
# 579  :  579 This is python programming
#
# 580  :  580 This is python programming
#
# 581  :  581 This is python programming
#
# 582  :  582 This is python programming
#
# 583  :  583 This is python programming
#
# 584  :  584 This is python programming
#
# 585  :  585 This is python programming
#
# 586  :  586 This is python programming
#
# 587  :  587 This is python programming
#
# 588  :  588 This is python programming
#
# 589  :  589 This is python programming
#
# 590  :  590 This is python programming
#
# 591  :  591 This is python programming
#
# 592  :  592 This is python programming
#
# 593  :  593 This is python programming
#
# 594  :  594 This is python programming
#
# 595  :  595 This is python programming
#
# 596  :  596 This is python programming
#
# 597  :  597 This is python programming
#
# 598  :  598 This is python programming
#
# 599  :  599 This is python programming
#
# 600  :  600 This is python programming
#
# 601  :  601 This is python programming
#
# 602  :  602 This is python programming
#
# 603  :  603 This is python programming
#
# 604  :  604 This is python programming
#
# 605  :  605 This is python programming
#
# 606  :  606 This is python programming
#
# 607  :  607 This is python programming
#
# 608  :  608 This is python programming
#
# 609  :  609 This is python programming
#
# 610  :  610 This is python programming
#
# 611  :  611 This is python programming
#
# 612  :  612 This is python programming
#
# 613  :  613 This is python programming
#
# 614  :  614 This is python programming
#
# 615  :  615 This is python programming
#
# 616  :  616 This is python programming
#
# 617  :  617 This is python programming
#
# 618  :  618 This is python programming
#
# 619  :  619 This is python programming
#
# 620  :  620 This is python programming
#
# 621  :  621 This is python programming
#
# 622  :  622 This is python programming
#
# 623  :  623 This is python programming
#
# 624  :  624 This is python programming
#
# 625  :  625 This is python programming
#
# 626  :  626 This is python programming
#
# 627  :  627 This is python programming
#
# 628  :  628 This is python programming
#
# 629  :  629 This is python programming
#
# 630  :  630 This is python programming
#
# 631  :  631 This is python programming
#
# 632  :  632 This is python programming
#
# 633  :  633 This is python programming
#
# 634  :  634 This is python programming
#
# 635  :  635 This is python programming
#
# 636  :  636 This is python programming
#
# 637  :  637 This is python programming
#
# 638  :  638 This is python programming
#
# 639  :  639 This is python programming
#
# 640  :  640 This is python programming
#
# 641  :  641 This is python programming
#
# 642  :  642 This is python programming
#
# 643  :  643 This is python programming
#
# 644  :  644 This is python programming
#
# 645  :  645 This is python programming
#
# 646  :  646 This is python programming
#
# 647  :  647 This is python programming
#
# 648  :  648 This is python programming
#
# 649  :  649 This is python programming
#
# 650  :  650 This is python programming
#
# 651  :  651 This is python programming
#
# 652  :  652 This is python programming
#
# 653  :  653 This is python programming
#
# 654  :  654 This is python programming
#
# 655  :  655 This is python programming
#
# 656  :  656 This is python programming
#
# 657  :  657 This is python programming
#
# 658  :  658 This is python programming
#
# 659  :  659 This is python programming
#
# 660  :  660 This is python programming
#
# 661  :  661 This is python programming
#
# 662  :  662 This is python programming
#
# 663  :  663 This is python programming
#
# 664  :  664 This is python programming
#
# 665  :  665 This is python programming
#
# 666  :  666 This is python programming
#
# 667  :  667 This is python programming
#
# 668  :  668 This is python programming
#
# 669  :  669 This is python programming
#
# 670  :  670 This is python programming
#
# 671  :  671 This is python programming
#
# 672  :  672 This is python programming
#
# 673  :  673 This is python programming
#
# 674  :  674 This is python programming
#
# 675  :  675 This is python programming
#
# 676  :  676 This is python programming
#
# 677  :  677 This is python programming
#
# 678  :  678 This is python programming
#
# 679  :  679 This is python programming
#
# 680  :  680 This is python programming
#
# 681  :  681 This is python programming
#
# 682  :  682 This is python programming
#
# 683  :  683 This is python programming
#
# 684  :  684 This is python programming
#
# 685  :  685 This is python programming
#
# 686  :  686 This is python programming
#
# 687  :  687 This is python programming
#
# 688  :  688 This is python programming
#
# 689  :  689 This is python programming
#
# 690  :  690 This is python programming
#
# 691  :  691 This is python programming
#
# 692  :  692 This is python programming
#
# 693  :  693 This is python programming
#
# 694  :  694 This is python programming
#
# 695  :  695 This is python programming
#
# 696  :  696 This is python programming
#
# 697  :  697 This is python programming
#
# 698  :  698 This is python programming
#
# 699  :  699 This is python programming
#
# 700  :  700 This is python programming
#
# 701  :  701 This is python programming
#
# 702  :  702 This is python programming
#
# 703  :  703 This is python programming
#
# 704  :  704 This is python programming
#
# 705  :  705 This is python programming
#
# 706  :  706 This is python programming
#
# 707  :  707 This is python programming
#
# 708  :  708 This is python programming
#
# 709  :  709 This is python programming
#
# 710  :  710 This is python programming
#
# 711  :  711 This is python programming
#
# 712  :  712 This is python programming
#
# 713  :  713 This is python programming
#
# 714  :  714 This is python programming
#
# 715  :  715 This is python programming
#
# 716  :  716 This is python programming
#
# 717  :  717 This is python programming
#
# 718  :  718 This is python programming
#
# 719  :  719 This is python programming
#
# 720  :  720 This is python programming
#
# 721  :  721 This is python programming
#
# 722  :  722 This is python programming
#
# 723  :  723 This is python programming
#
# 724  :  724 This is python programming
#
# 725  :  725 This is python programming
#
# 726  :  726 This is python programming
#
# 727  :  727 This is python programming
#
# 728  :  728 This is python programming
#
# 729  :  729 This is python programming
#
# 730  :  730 This is python programming
#
# 731  :  731 This is python programming
#
# 732  :  732 This is python programming
#
# 733  :  733 This is python programming
#
# 734  :  734 This is python programming
#
# 735  :  735 This is python programming
#
# 736  :  736 This is python programming
#
# 737  :  737 This is python programming
#
# 738  :  738 This is python programming
#
# 739  :  739 This is python programming
#
# 740  :  740 This is python programming
#
# 741  :  741 This is python programming
#
# 742  :  742 This is python programming
#
# 743  :  743 This is python programming
#
# 744  :  744 This is python programming
#
# 745  :  745 This is python programming
#
# 746  :  746 This is python programming
#
# 747  :  747 This is python programming
#
# 748  :  748 This is python programming
#
# 749  :  749 This is python programming
#
# 750  :  750 This is python programming
#
# 751  :  751 This is python programming
#
# 752  :  752 This is python programming
#
# 753  :  753 This is python programming
#
# 754  :  754 This is python programming
#
# 755  :  755 This is python programming
#
# 756  :  756 This is python programming
#
# 757  :  757 This is python programming
#
# 758  :  758 This is python programming
#
# 759  :  759 This is python programming
#
# 760  :  760 This is python programming
#
# 761  :  761 This is python programming
#
# 762  :  762 This is python programming
# Hit any key to continue or 'q' to quit :  q
# List has been ended

# %%
#WAP to read a file that contains a python code with comments create a new file which copies the entire code but without comments
f1=open("file9.txt")
f2=open("file11.txt",'w')
for i in f1.readlines():
    f2.write(i[:i.find("#"):])
f2.close()

# %%
with open("file12.txt",'w') as F:
    F.write("HEllo")

# %%
F.closed
# Out:
# True

# %%
#WAP find change in duplicate file
f1=open("file9.txt")
f2=open("file13.txt")
count=count2=1
same=True
for i,j in zip(f1.readlines(),f2.readlines()):
    for k,l in zip(i,j):
        if k!=l:
            print(f"Line = {count} and columns = {count2}")
            same=False
            break
        count2+=1 
    count2=0
    count+=1
if same:
    print("Both are same")
# Out:
# Line = 2 and columns = 9

# %%
# %%writefile file14.txt
# INDIA IS MY COUNTRY
# Out:
# Overwriting file14.txt

# %%
#WAP TO READ A FILE WHICH SHOWS ALL THE VALUES AND WORDS IN IT BUT REVERSE THE WORD THAT STARTS WITH 'I'
F1=open("file14.txt")
for i in F1.readline().split():
    if i[0].lower()=='i':
        print(i[::-1],end=" ")
    else:
        print(i,end=" ")
# Out:
# AIDNI SI MY COUNTRY

# %%
# %%writefile file15.txt
# APPLE
# GREENAPPLE
# ORANGES
# BANANAS
# Out:
# Writing file15.txt

# %% [markdown]
# ## WAP USING A file which consists of multiple statements find all the words from that file that can be made using set of characters given by user

# %%
F1=open("file15.txt")
LT=eval(input("Enter letters (in list): "))
A=[]
for i in F1.readlines():
    for j in i:
        if j in LT:
            A.append(i)
    if A.count(i)>=len(LT):
        print(i)
# Out:
# Enter letters (in list):  ['A','N']
# GREENAPPLE
#
# ORANGES
#
# BANANAS
